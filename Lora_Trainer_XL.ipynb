# %% [markdown]
# <a href="https://colab.research.google.com/github/zhupeter010903/lora_training/blob/main/Lora_Trainer_XL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌟 XL Lora Trainer by Hollowstrawberry
#
# Colab Premium is recommended. Ideally you'd be changing the runtime to an A100 and use the maximum batch size, it will be several times faster.
#
# This colab is possible by open source code from talented people:
# * [kohya-ss](https://github.com/kohya-ss/sd-scripts)
# * [derrian-distro](https://github.com/derrian-distro/LoRA_Easy_Training_scripts_Backend/)
# * [Linaqruf](https://github.com/Linaqruf/kohya-trainer)
# * [Jelosus2](https://github.com/Jelosus2/LoRA_Easy_Training_Colab)

# %% [markdown]
# ### ⭕ Disclaimer
# The purpose of this document is to research bleeding-edge technologies in the field of machine learning.
# Please read and follow the [Google Colab guidelines](https://research.google.com/colaboratory/faq.html) and its [Terms of Service](https://research.google.com/colaboratory/tos_v3.html).

# %% [markdown]
# | |GitHub|🇬🇧 English|🇪🇸 Spanish|
# |:--|:-:|:-:|:-:|
# | 🏠 **Homepage** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab) | | |
# | 📊 **Dataset Maker** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Dataset_Maker.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Dataset_Maker.ipynb) | [![Abrir en Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge-spanish.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Spanish_Dataset_Maker.ipynb) |
# | ⭐ **Lora Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb) | [![Abrir en Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge-spanish.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Spanish_Lora_Trainer.ipynb) |
# | 🌟 **XL Lora Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL.ipynb) |  |
# | 🌟 **Legacy XL Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL_Legacy.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL_Legacy.ipynb) |  |

# %%
import os
import re
import toml
from time import time
from IPython.display import Markdown, display
import warnings

warnings.filterwarnings("ignore")

# These carry information from past executions
if "model_url" in globals():
  old_model_url = model_url
else:
  old_model_url = None
if "dependencies_installed" not in globals():
  dependencies_installed = False
if "model_file" not in globals():
  model_file = None

# These may be set by other cells, some are legacy
if "custom_dataset" not in globals():
  custom_dataset = None
if "override_dataset_config_file" not in globals():
  override_dataset_config_file = None
if "continue_from_lora" not in globals():
  continue_from_lora = ""
if "override_config_file" not in globals():
  override_config_file = None

#try:
#  LOWRAM = int(next(line.split()[1] for line in open('/proc/meminfo') if "MemTotal" in line)) / (1024**2) < 15
#except:
#  LOWRAM = True

COMMIT = "47ef6ed843ee1951cd07838c5fdcca60c954130c"
LOWRAM = True
LOAD_TRUNCATED_IMAGES = True
BETTER_EPOCH_NAMES = True
FIX_DIFFUSERS = True


#@title ## 🚩 Start Here

#@markdown ### ▶️ Setup
#@markdown Your project name will be the same as the folder containing your images. Spaces aren't allowed.
project_name = "cecily_noein" #@param {type:"string"}
project_name = project_name.strip()
#@markdown The folder structure doesn't matter and is purely for comfort. Make sure to always pick the same one. I like organizing by project.
folder_structure = "Organize by project (MyDrive/Loras/project_name/dataset)" #@param ["Organize by category (MyDrive/lora_training/datasets/project_name)", "Organize by project (MyDrive/Loras/project_name/dataset)"]
#@markdown Decide the model that will be downloaded and used for training. You can also choose your own by pasting its download link, or a file in your Google Drive starting with `/content/drive/MyDrive`.
training_model = "NoobAI Eps 1.1" #@param ["Pony Diffusion V6 XL", "Illustrious XL 0.1", "NoobAI V-Pred 1.0", "NoobAI Eps 1.1", "Animagine XL V3", "Stable Diffusion XL 1.0 base"]
optional_custom_training_model = "" #@param {type:"string"}
custom_model_is_diffusers = False #@param {type:"boolean"}
custom_model_is_vpred = False #@param {type:"boolean"}
#@markdown Use wandb if you want to visualize the progress of your training over time.
wandb_key = "" #@param {type:"string"}

load_diffusers = custom_model_is_diffusers and len(optional_custom_training_model) > 0
vpred = custom_model_is_vpred and len(optional_custom_training_model) > 0

if optional_custom_training_model:
  model_url = optional_custom_training_model
elif "Pony" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/hollowstrawberry/67AB2F"
  else:
    model_url = "https://civitai.com/api/download/models/290640"
    model_file = "/content/ponyDiffusionV6XL.safetensors"
elif "Animagine" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/cagliostrolab/animagine-xl-3.0"
  else:
    model_url = "https://civitai.com/api/download/models/293564"
    model_file = "/content/animagineXLV3.safetensors"
elif "Illustrious" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/OnomaAIResearch/Illustrious-xl-early-release-v0"
  else:
    model_url = "https://huggingface.co/OnomaAIResearch/Illustrious-xl-early-release-v0/resolve/main/Illustrious-XL-v0.1.safetensors"
elif "NoobAI Eps" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-1.1"
  else:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-1.1/resolve/main/NoobAI-XL-v1.1.safetensors"
elif "NoobAI V-Pred" in training_model:
  vpred = True
  if load_diffusers:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-Vpred-1.0"
  else:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-Vpred-1.0/resolve/main/NoobAI-XL-Vpred-v1.0.safetensors"
else:
  if load_diffusers:
    model_url = "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0"
  else:
    model_url = "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors"

if load_diffusers:
  vae_file = "stabilityai/sdxl-vae"
else:
  vae_url = "https://huggingface.co/stabilityai/sdxl-vae/resolve/main/sdxl_vae.safetensors"
  vae_file = "/content/sdxl_vae.safetensors"

model_url = model_url.strip()

#@markdown ### ▶️ Processing
resolution = 1024 #param {type:"slider", min:768, max:1536, step:128}
caption_extension = ".txt" #@param [".txt", ".caption"]
#@markdown Shuffling anime tags in place improves learning and prompting. An activation tag goes at the start of every text file and will not be shuffled.<p>
shuffle_tags = True #@param {type:"boolean"}
shuffle_caption = shuffle_tags
activation_tags = "2" #@param [0,1,2,3]
keep_tokens = int(activation_tags)

#@markdown ### ▶️ Steps <p>
#@markdown Your images will repeat this number of times during training. I recommend that your images multiplied by their repeats is around 100, or 1 repeat with more than 100 images.
num_repeats = 2 #@param {type:"number"}
#@markdown Choose how long you want to train for. A good starting point is around 10 epochs or around 2000 steps.<p>
#@markdown One epoch is a number of steps equal to: your number of images multiplied by their repeats, divided by batch size. <p>
preferred_unit = "Epochs" #@param ["Epochs", "Steps"]
how_many = 20 #@param {type:"number"}
max_train_epochs = how_many if preferred_unit == "Epochs" else None
max_train_steps = how_many if preferred_unit == "Steps" else None
#@markdown Saving more epochs will let you compare your Lora's progress better.
save_every_n_epochs = 1 #@param {type:"number"}
keep_only_last_n_epochs = 10 #@param {type:"number"}
if not save_every_n_epochs:
  save_every_n_epochs = max_train_epochs
if not keep_only_last_n_epochs:
  keep_only_last_n_epochs = max_train_epochs

#@markdown ### ▶️ Learning
#@markdown The learning rate is the most important for your results. If your Lora produces black images, lower the unet and text encoder to 1e-4 and 1e-5 respectively, or even lower. <p>
#@markdown If you're training a style you can choose to set the text encoder to 0.
unet_lr = 3e-4 #@param {type:"number"}
text_encoder_lr = 6e-5 #@param {type:"number"}
#@markdown The scheduler is the algorithm that guides the learning rate. If you're not sure, pick `constant` and ignore the number. I personally recommend `cosine_with_restarts` with 3 restarts.
lr_scheduler = "cosine_with_restarts" #@param ["constant", "cosine", "cosine_with_restarts", "constant_with_warmup", "linear", "polynomial", "rex"]
lr_scheduler_number = 3 #@param {type:"number"}
#@markdown Steps spent "warming up" the learning rate during training for efficiency. I recommend leaving it at 5%.
lr_warmup_ratio = 0.05 #@param {type:"slider", min:0.0, max:0.2, step:0.01}
lr_warmup_steps = 0
#@markdown These settings may produce better results. min_snr_gamma adjusts loss over time. ip_noise_gamma adjusts random noise.
min_snr_gamma_enabled = True #@param {type:"boolean"}
min_snr_gamma = 8.0 #@param {type:"slider", min:4, max:16.0, step:0.5}
ip_noise_gamma_enabled = False #@param {type:"boolean"}
ip_noise_gamma = 0.05 #@param {type:"slider", min:0.05, max:0.1, step:0.01}
#@markdown Multinoise may help with color balance (darker darks, lighter lights).
multinoise = True #@param {type:"boolean"}

#@markdown ### ▶️ Structure
#@markdown LoRA is the classic type and good for a variety of purposes. LoCon is good with artstyles as it has more layers to learn more aspects of the dataset.
lora_type = "LoRA" #@param ["LoRA", "LoCon"]

#@markdown Below are some recommended XL values for the following settings:

#@markdown | type | network_dim | network_alpha | conv_dim | conv_alpha |
#@markdown | :---: | :---: | :---: | :---: | :---: |
#@markdown | Regular LoRA | 8 | 4 |   |   |
#@markdown | Style LoCon | 16 | 8 | 16 | 8 |

#@markdown More dim means larger Lora, it can hold more information but more isn't always better.
network_dim = 8 #@param {type:"slider", min:1, max:32, step:1}
network_alpha = 4 #@param {type:"slider", min:1, max:32, step:1}
#@markdown The following two values only apply to the additional layers of LoCon.
conv_dim = 16 #@param {type:"slider", min:1, max:32, step:1}
conv_alpha = 8 #@param {type:"slider", min:1, max:32, step:1}

network_module = "networks.lora"
network_args = None
if lora_type.lower() == "locon":
  network_args = [f"conv_dim={conv_dim}", f"conv_alpha={conv_alpha}"]

#@markdown ### ▶️ Training
#@markdown Adjust these parameters depending on your colab configuration.
#@markdown
#@markdown Higher batch size is often faster but uses more memory.
train_batch_size = 4 #@param {type:"slider", min:1, max:16, step:1}
#@markdown I have found no substantial difference between sdpa and xformers.
cross_attention = "sdpa" #@param ["sdpa", "xformers"]
#@markdown Use `full fp16` for lowest memory usage. The `bf16` options may not work correctly on the free GPU tier.<p>
#@markdown The Lora will be trained with the selected precision, but will always be saved in fp16 format for compatibility reasons.
precision = "full fp16" #@param ["float", "full fp16", "full bf16", "mixed fp16", "mixed bf16"]
#@markdown Caching latents to drive will add a 250KB file next to each image but will use considerably less memory.
cache_latents = True #@param {type:"boolean"}
cache_latents_to_drive = True #@param {type:"boolean"}
#@markdown The following option will turn off shuffle_tags and disable text encoder training.
cache_text_encoder_outputs  = False  # @param {type:"boolean"}

mixed_precision = "no"
if "fp16" in precision:
  mixed_precision = "fp16"
elif "bf16" in precision:
  mixed_precision = "bf16"
full_precision = "full" in precision

#@markdown ### ▶️ Advanced
#@markdown The optimizer is the algorithm used for training. AdamW8bit is the default and works great, while Prodigy manages learning rate automatically and may have several advantages such as training faster due to needing less steps as well as working better for small datasets.
optimizer = "AdamW8bit" #@param ["AdamW8bit", "Prodigy", "DAdaptation", "DadaptAdam", "DadaptLion", "AdamW", "Lion", "SGDNesterov", "SGDNesterov8bit", "AdaFactor", "Came"]
#@markdown Recommended args for AdamW8bit: `weight_decay=0.1 betas=[0.9,0.99]`<p>
#@markdown Recommended args for Prodigy: `decouple=True weight_decay=0.01 betas=[0.9,0.999] d_coef=2 use_bias_correction=True safeguard_warmup=True`<p>
#@markdown Recommended args for AdaFactor: `scale_parameter=False relative_step=False warmup_init=False`<p>
#@markdown Recommended args for Came: `weight_decay=0.04`<p>
#@markdown If Dadapt or Prodigy are selected and the recommended box is checked, the following values will override any previous settings:<p>
#@markdown `unet_lr=0.75`, `text_encoder_lr=0.75`, `network_alpha=network_dim`, `full_precision=False`<p>
recommended_values = True #@param {type:"boolean"}
#@markdown Alternatively set your own optimizer arguments separated by spaces (not commas). Recommended box must be disabled.
optimizer_args = "" #@param {type:"string"}
optimizer_args = [a.strip() for a in optimizer_args.split(' ') if a]

if recommended_values:
  if any(opt in optimizer.lower() for opt in ["dadapt", "prodigy"]):
    unet_lr = 0.75
    text_encoder_lr = 0.75
    network_alpha = network_dim
    full_precision = False
  if optimizer == "Prodigy":
    optimizer_args = ["decouple=True", "weight_decay=0.01", "betas=[0.9,0.999]", "d_coef=2", "use_bias_correction=True", "safeguard_warmup=True"]
  elif optimizer == "AdamW8bit":
    optimizer_args = ["weight_decay=0.1", "betas=[0.9,0.99]"]
  elif optimizer == "AdaFactor":
    optimizer_args = ["scale_parameter=False", "relative_step=False", "warmup_init=False"]
  elif optimizer == "Came":
    optimizer_args = ["weight_decay=0.04"]

if optimizer == "Came":
  optimizer = "LoraEasyCustomOptimizer.came.CAME"

lr_scheduler_type = None
lr_scheduler_args = None
lr_scheduler_num_cycles = lr_scheduler_number
lr_scheduler_power = lr_scheduler_number

if "rex" in lr_scheduler:
  lr_scheduler = "cosine"
  lr_scheduler_type = "LoraEasyCustomOptimizer.RexAnnealingWarmRestarts.RexAnnealingWarmRestarts"
  lr_scheduler_args = ["min_lr=1e-9", "gamma=0.9", "d=0.9"]

# Misc
seed = 42
gradient_accumulation_steps = 1
bucket_reso_steps = 64
min_bucket_reso = 256
max_bucket_reso = 4096


#@markdown ### ▶️ Ready
#@markdown You can now run this cell to cook your Lora. Good luck! <p>


# 👩‍💻 Cool code goes here

root_dir = "/content"
trainer_dir = os.path.join(root_dir, "trainer")
kohya_dir = os.path.join(trainer_dir, "sd_scripts")

venv_python = os.path.join(kohya_dir, "venv/bin/python")
venv_pip = os.path.join(kohya_dir, "venv/bin/pip")
train_network = os.path.join(kohya_dir, "sdxl_train_network.py")

if "/Loras" in folder_structure:
  main_dir      = os.path.join(root_dir, "drive/MyDrive/Loras")
  log_folder    = os.path.join(main_dir, "_logs")
  config_folder = os.path.join(main_dir, project_name)
  images_folder = os.path.join(main_dir, project_name, "dataset")
  output_folder = os.path.join(main_dir, project_name, "output")
else:
  main_dir      = os.path.join(root_dir, "drive/MyDrive/lora_training")
  images_folder = os.path.join(main_dir, "datasets", project_name)
  output_folder = os.path.join(main_dir, "output", project_name)
  config_folder = os.path.join(main_dir, "config", project_name)
  log_folder    = os.path.join(main_dir, "log")

config_file = os.path.join(config_folder, "training_config.toml")
dataset_config_file = os.path.join(config_folder, "dataset_config.toml")


def install_trainer():
  # !apt -y update -qq
  # !apt install -y python3.10-venv aria2 -qq
  # !git clone https://github.com/derrian-distro/LoRA_Easy_Training_scripts_Backend {trainer_dir}
  os.chdir(trainer_dir)
  # !git reset --hard {COMMIT}
  # !chmod 755 ./colab_install.sh
  # !./colab_install.sh

  # fix logging
  # !{venv_pip} uninstall -y rich

  # patch kohya
  os.chdir(kohya_dir)
  if LOAD_TRUNCATED_IMAGES:
    # !sed -i 's/from PIL import Image/from PIL import Image, ImageFile\nImageFile.LOAD_TRUNCATED_IMAGES=True/g' library/train_util.py # fix truncated jpegs error
  if BETTER_EPOCH_NAMES:
    # !sed -i 's/{:06d}/{:02d}/g' library/train_util.py # make epoch names shorter
    # !sed -i 's/"." + args.save_model_as)/"-{:02d}.".format(num_train_epochs) + args.save_model_as)/g' train_network.py # name of the last epoch will match the rest
  if FIX_DIFFUSERS:
    deprecation_utils = os.path.join(kohya_dir, "venv/lib/python3.10/site-packages/diffusers/utils/deprecation_utils.py")
    # !sed -i 's/if version.parse/if False:#/g' {deprecation_utils}
  if wandb_key:
    # !sed -i 's/accelerator.log(logs, step=epoch + 1)//g' train_network.py  # fix warning
    # !sed -i 's/accelerator.log(logs, step=epoch + 1)//g' sdxl_train.py  # fix warning

  os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
  os.environ["BITSANDBYTES_NOWELCOME"] = "1"
  os.environ["SAFETENSORS_FAST_GPU"] = "1"
  os.environ["PYTHONWARNINGS"] = "ignore"
  os.chdir(root_dir)


def validate_dataset():
  global lr_warmup_steps, lr_warmup_ratio, caption_extension, keep_tokens, model_url
  supported_types = (".png", ".jpg", ".jpeg", ".webp", ".bmp")

  if model_url.startswith("/content/drive/") and not os.path.exists(model_url):
    print("💥 Error: The custom training model you specified was not found in your Google Drive.")
    return

  print("\n💿 Checking dataset...")
  if not project_name.strip() or any(c in project_name for c in " .()\"'\\/"):
    print("💥 Error: Please choose a valid project name.")
    return

  # Find the folders and files
  if custom_dataset:
    try:
      datconf = toml.loads(custom_dataset)
      datasets = [d for d in datconf["datasets"][0]["subsets"]]
    except:
      print(f"💥 Error: Your custom dataset is invalid or contains an error! Please check the original template.")
      return
    reg = [d.get("image_dir") for d in datasets if d.get("is_reg", False)]
    datasets_dict = {d["image_dir"]: d["num_repeats"] for d in datasets}
    folders = datasets_dict.keys()
    files = [f for folder in folders for f in os.listdir(folder)]
    images_repeats = {folder: (len([f for f in os.listdir(folder) if f.lower().endswith(supported_types)]), datasets_dict[folder]) for folder in folders}
  else:
    reg = []
    folders = [images_folder]
    files = os.listdir(images_folder)
    images_repeats = {images_folder: (len([f for f in files if f.lower().endswith(supported_types)]), num_repeats)}

  # Validation
  for folder in folders:
    if not os.path.exists(folder):
      print(f"💥 Error: The folder {folder.replace('/content/drive/', '')} doesn't exist.")
      return
  for folder, (img, rep) in images_repeats.items():
    if not img:
      print(f"💥 Error: Your {folder.replace('/content/drive/', '')} folder is empty.")
      return
  test_files = []
  for f in files:
    if not f.lower().endswith((caption_extension, ".npz")) and not f.lower().endswith(supported_types):
      print(f"💥 Error: Invalid file in dataset: \"{f}\". Aborting.")
      return
    for ff in test_files:
      if f.endswith(supported_types) and ff.endswith(supported_types) \
          and os.path.splitext(f)[0] == os.path.splitext(ff)[0]:
        print(f"💥 Error: The files {f} and {ff} cannot have the same name. Aborting.")
        return
    test_files.append(f)

  if caption_extension and not [txt for txt in files if txt.lower().endswith(caption_extension)]:
    caption_extension = ""
  if continue_from_lora and not (continue_from_lora.endswith(".safetensors") and os.path.exists(continue_from_lora)):
    print(f"💥 Error: Invalid path to existing Lora. Example: /content/drive/MyDrive/Loras/example.safetensors")
    return

  # Show estimations to the user

  pre_steps_per_epoch = sum(img*rep for (img, rep) in images_repeats.values())
  steps_per_epoch = pre_steps_per_epoch/train_batch_size
  total_steps = max_train_steps or int(max_train_epochs*steps_per_epoch)
  estimated_epochs = int(total_steps/steps_per_epoch)
  lr_warmup_steps = int(total_steps*lr_warmup_ratio)

  for folder, (img, rep) in images_repeats.items():
    print("📁"+folder.replace("/content/drive/", "") + (" (Regularization)" if folder in reg else ""))
    print(f"📈 Found {img} images with {rep} repeats, equaling {img*rep} steps.")
  print(f"📉 Divide {pre_steps_per_epoch} steps by {train_batch_size} batch size to get {steps_per_epoch} steps per epoch.")
  if max_train_epochs:
    print(f"🔮 There will be {max_train_epochs} epochs, for around {total_steps} total training steps.")
  else:
    print(f"🔮 There will be {total_steps} steps, divided into {estimated_epochs} epochs and then some.")

  if total_steps > 10000:
    print("💥 Error: Your total steps are too high. You probably made a mistake. Aborting...")
    return

  return True


def create_config():
  global dataset_config_file, config_file, model_file

  if override_config_file:
    config_file = override_config_file
    print(f"\n⭕ Using custom config file {config_file}")
  else:
    config_dict = {
      "network_arguments": {
        "unet_lr": unet_lr,
        "text_encoder_lr": text_encoder_lr if not cache_text_encoder_outputs else 0,
        "network_dim": network_dim,
        "network_alpha": network_alpha,
        "network_module": network_module,
        "network_args": network_args,
        "network_train_unet_only": text_encoder_lr == 0 or cache_text_encoder_outputs,
        "network_weights": continue_from_lora or None
      },
      "optimizer_arguments": {
        "learning_rate": unet_lr,
        "lr_scheduler": lr_scheduler,
        "lr_scheduler_type": lr_scheduler_type,
        "lr_scheduler_args": lr_scheduler_args,
        "lr_scheduler_num_cycles": lr_scheduler_num_cycles if lr_scheduler == "cosine_with_restarts" else None,
        "lr_scheduler_power": lr_scheduler_power if lr_scheduler == "polynomial" else None,
        "lr_warmup_steps": lr_warmup_steps if lr_scheduler not in ("cosine", "constant") else None,
        "optimizer_type": optimizer,
        "optimizer_args": optimizer_args or None,
        "loss_type": "l2",
        "max_grad_norm": 1.0,
      },
      "training_arguments": {
        "lowram": LOWRAM,
        "pretrained_model_name_or_path": model_file,
        "vae": vae_file,
        "max_train_steps": max_train_steps,
        "max_train_epochs": max_train_epochs,
        "train_batch_size": train_batch_size,
        "seed": seed,
        "max_token_length": 225,
        "xformers": cross_attention == "xformers",
        "sdpa": cross_attention == "sdpa",
        "min_snr_gamma": min_snr_gamma if min_snr_gamma_enabled else None,
        "ip_noise_gamma": ip_noise_gamma if ip_noise_gamma_enabled else None,
        "no_half_vae": True,
        "gradient_checkpointing": True,
        "gradient_accumulation_steps": gradient_accumulation_steps,
        "max_data_loader_n_workers": 1,
        "persistent_data_loader_workers": True,
        "mixed_precision": mixed_precision,
        "full_fp16": mixed_precision == "fp16" and full_precision,
        "full_bf16": mixed_precision == "bf16" and full_precision,
        "cache_latents": cache_latents,
        "cache_latents_to_disk": cache_latents_to_drive,
        "cache_text_encoder_outputs": cache_text_encoder_outputs,
        "min_timestep": 0,
        "max_timestep": 1000,
        "prior_loss_weight": 1.0,
        "multires_noise_iterations": 6 if multinoise else None,
        "multires_noise_discount": 0.3 if multinoise else None,
        "v_parameterization": vpred or None,
        "scale_v_pred_loss_like_noise_pred": vpred or None,
        "zero_terminal_snr": vpred or None,
      },
      "saving_arguments": {
        "save_precision": "fp16",
        "save_model_as": "safetensors",
        "save_every_n_epochs": save_every_n_epochs,
        "save_last_n_epochs": keep_only_last_n_epochs,
        "output_name": project_name,
        "output_dir": output_folder,
        "log_prefix": project_name,
        "logging_dir": log_folder,
        "wandb_api_key": wandb_key or None,
        "log_with": "wandb" if wandb_key else None,
      }
    }

    for key in config_dict:
      if isinstance(config_dict[key], dict):
        config_dict[key] = {k: v for k, v in config_dict[key].items() if v is not None}

    with open(config_file, "w") as f:
      f.write(toml.dumps(config_dict))
    print(f"\n📄 Config saved to {config_file}")

  if override_dataset_config_file:
    dataset_config_file = override_dataset_config_file
    print(f"⭕ Using custom dataset config file {dataset_config_file}")
  else:
    dataset_config_dict = {
      "general": {
        "resolution": resolution,
        "shuffle_caption": shuffle_caption and not cache_text_encoder_outputs,
        "keep_tokens": keep_tokens,
        "flip_aug": False,
        "caption_extension": caption_extension,
        "enable_bucket": True,
        "bucket_no_upscale": False,
        "bucket_reso_steps": bucket_reso_steps,
        "min_bucket_reso": min_bucket_reso,
        "max_bucket_reso": max_bucket_reso,
      },
      "datasets": toml.loads(custom_dataset)["datasets"] if custom_dataset else [
        {
          "subsets": [
            {
              "num_repeats": num_repeats,
              "image_dir": images_folder,
              "class_tokens": None if caption_extension else project_name
            }
          ]
        }
      ]
    }

    for key in dataset_config_dict:
      if isinstance(dataset_config_dict[key], dict):
        dataset_config_dict[key] = {k: v for k, v in dataset_config_dict[key].items() if v is not None}

    with open(dataset_config_file, "w") as f:
      f.write(toml.dumps(dataset_config_dict))
    print(f"📄 Dataset config saved to {dataset_config_file}")


def download_model():
  global old_model_url, model_url, model_file, vae_url, vae_file
  real_model_url = model_url  # There was a reason for having a separate variable but I forgot what it was.

  if real_model_url.startswith("/content/drive/"):
    # Local model, already checked to exist
    model_file = real_model_url
    print(f"📁 Using local model file: {model_file}")

    # Download VAE
    if not os.path.exists(vae_file):
      # !aria2c "{vae_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{vae_file}"

    # Validation
    if model_file.lower().endswith(".safetensors"):
      from safetensors.torch import load_file as load_safetensors
      try:
        test = load_safetensors(model_file)
        del test
      except:
        return False
    elif model_file.lower().endswith(".ckpt"):
      from torch import load as load_ckpt
      try:
        test = load_ckpt(model_file)
        del test
      except:
        return False
    return True

  else:
    # Downloadable model
    if load_diffusers:
      if 'huggingface.co' in real_model_url:
          match = re.search(r'huggingface\.co/([^/]+)/([^/]+)', real_model_url)
          if match:
              username = match.group(1)
              model_name = match.group(2)
              model_file = f"{username}/{model_name}"
              from huggingface_hub import HfFileSystem
              fs = HfFileSystem()
              existing_folders = set(fs.ls(model_file, detail=False))
              necessary_folders = [ "scheduler", "text_encoder", "text_encoder_2", "tokenizer", "tokenizer_2", "unet", "vae" ]
              if all(f"{model_file}/{folder}" in existing_folders for folder in necessary_folders):
                print("🍃 Diffusers model identified.")  # Will be handled by kohya
                return True
      raise ValueError("💥 Failed to load Diffusers model. If this model is not Diffusers, have you tried turning it off at the top of the colab?")

    # Define local filename
    if not model_file or old_model_url and old_model_url != model_url:
      if real_model_url.lower().endswith((".ckpt", ".safetensors")):
        model_file = f"/content{real_model_url[real_model_url.rfind('/'):]}"
      else:
        model_file = "/content/downloaded_model.safetensors"
        if os.path.exists(model_file):
          # !rm "{model_file}"

    # HuggingFace
    if m := re.search(r"(?:https?://)?(?:www\.)?huggingface\.co/[^/]+/[^/]+/blob", real_model_url):
      real_model_url = real_model_url.replace("blob", "resolve")
    # Civitai
    elif m := re.search(r"(?:https?://)?(?:www\\.)?civitai\.com/models/([0-9]+)(/[A-Za-z0-9-_]+)?", real_model_url):
      if m.group(2):
        model_file = f"/content{m.group(2)}.safetensors"
      if m := re.search(r"modelVersionId=([0-9]+)", real_model_url):
        real_model_url = f"https://civitai.com/api/download/models/{m.group(1)}"
      else:
        raise ValueError("💥 optional_custom_training_model contains a civitai link, but the link doesn't include a modelVersionId. You can also right click the download button to copy the direct download link.")

    # Download checkpoint
    # !aria2c "{real_model_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{model_file}"

    # Download VAE
    if not os.path.exists(vae_file):
      # !aria2c "{vae_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{vae_file}"

    # Validation

    if model_file.lower().endswith(".safetensors"):
      from safetensors.torch import load_file as load_safetensors
      try:
        test = load_safetensors(model_file)
        del test
      except:
        new_model_file = os.path.splitext(model_file)[0]+".ckpt"
        # !mv "{model_file}" "{new_model_file}"
        model_file = new_model_file
        print(f"Renamed model to {os.path.splitext(model_file)[0]}.ckpt")

    if model_file.lower().endswith(".ckpt"):
      from torch import load as load_ckpt
      try:
        test = load_ckpt(model_file)
        del test
      except:
        return False

  return True


def calculate_rex_steps():
  # https://github.com/derrian-distro/LoRA_Easy_Training_scripts_Backend/blob/c34084b0435e6e19bb7a01ac1ecbadd185ee8c1e/utils/validation.py#L268
  global max_train_steps
  print("\n🤔 Calculating Rex steps")
  if max_train_steps:
    calculated_max_steps = max_train_steps
  else:
    from library.train_util import BucketManager
    from PIL import Image
    from pathlib import Path
    import math

    with open(dataset_config_file, "r") as f:
      subsets = toml.load(f)["datasets"][0]["subsets"]

    supported_types = [".png", ".jpg", ".jpeg", ".webp", ".bmp"]
    res = (resolution, resolution)
    bucketManager = BucketManager(False, res, min_bucket_reso, max_bucket_reso, bucket_reso_steps)
    bucketManager.make_buckets()
    for subset in subsets:
        for image in Path(subset["image_dir"]).iterdir():
            if image.suffix not in supported_types:
                continue
            with Image.open(image) as img:
                bucket_reso, _, _ = bucketManager.select_bucket(img.width, img.height)
                for _ in range(subset["num_repeats"]):
                    bucketManager.add_image(bucket_reso, image)
    steps_before_acc = sum(math.ceil(len(bucket) / train_batch_size) for bucket in bucketManager.buckets)
    calculated_max_steps = math.ceil(steps_before_acc / gradient_accumulation_steps) * max_train_epochs
    del bucketManager

  cycle_steps = calculated_max_steps // (lr_scheduler_num_cycles or 1)
  print(f"  cycle steps: {cycle_steps}")
  lr_scheduler_args.append(f"first_cycle_max_steps={cycle_steps}")

  warmup_steps = round(calculated_max_steps * lr_warmup_ratio) // (lr_scheduler_num_cycles or 1)
  if warmup_steps > 0:
    print(f"  warmup steps: {warmup_steps}")
    lr_scheduler_args.append(f"warmup_steps={warmup_steps}")


def main():
  global dependencies_installed

  if not os.path.exists('/content/drive'):
    from google.colab import drive
    print("📂 Connecting to Google Drive...")
    drive.mount('/content/drive')

  for dir in (main_dir, trainer_dir, log_folder, images_folder, output_folder, config_folder):
    os.makedirs(dir, exist_ok=True)

  if not validate_dataset():
    return

  if not dependencies_installed:
    print("\n🏭 Installing trainer...\n")
    t0 = time()
    install_trainer()
    t1 = time()
    dependencies_installed = True
    print(f"\n✅ Installation finished in {int(t1-t0)} seconds.")
  else:
    print("\n✅ Dependencies already installed.")

  if old_model_url != model_url or not model_file or not os.path.exists(model_file):
    print("\n🔄 Getting model...")
    if not download_model():
      print("\n💥 Error: The model you specified is invalid or corrupted."
            "\nIf you're using an URL, please check that the model is accessible without being logged in."
            "\nYou can try civitai or huggingface URLs, or a path in your Google Drive starting with /content/drive/MyDrive")
      return
    print()
  else:
    print("\n🔄 Model already downloaded.\n")

  if lr_scheduler_type:
    create_config()
    os.chdir(kohya_dir)
    calculate_rex_steps()
    os.chdir(root_dir)

  create_config()

  print("\n⭐ Starting trainer...\n")

  os.chdir(kohya_dir)
  # !{venv_python} {train_network} --config_file={config_file} --dataset_config={dataset_config_file}
  os.chdir(root_dir)

  if not get_ipython().__dict__['user_ns']['_exit_code']:
    display(Markdown("### ✅ Done! [Go download your Lora from Google Drive](https://drive.google.com/drive/my-drive)\n"
                     "### There will be several files, you should try the latest version (the file with the largest number next to it)"))

main()
# Out:
# 💿 Checking dataset...
# 📁MyDrive/Loras/cecily_noein/dataset/cecily_cg
# 📈 Found 73 images with 1 repeats, equaling 73 steps.
# 📁MyDrive/Loras/cecily_noein/dataset/cecily_manga
# 📈 Found 100 images with 1 repeats, equaling 100 steps.
# 📁MyDrive/Loras/cecily_noein/dataset/cecily_portrait
# 📈 Found 45 images with 1 repeats, equaling 45 steps.
# 📁MyDrive/Loras/cecily_noein/dataset/noein
# 📈 Found 52 images with 1 repeats, equaling 52 steps.
# 📁MyDrive/Loras/cecily_noein/dataset/noein_manga
# 📈 Found 47 images with 1 repeats, equaling 47 steps.
# 📁MyDrive/Loras/cecily_noein/dataset/bundus
# 📈 Found 6 images with 1 repeats, equaling 6 steps.
# 📁MyDrive/Loras/cecily_noein/dataset/cecily_noein
# 📈 Found 20 images with 1 repeats, equaling 20 steps.
# 📁MyDrive/Loras/cecily_noein/dataset/cecily_noein_manga
# 📈 Found 36 images with 1 repeats, equaling 36 steps.
# 📁MyDrive/Loras/cecily_noein/dataset/cecily_bundus
# 📈 Found 5 images with 1 repeats, equaling 5 steps.
# 📉 Divide 384 steps by 4 batch size to get 96.0 steps per epoch.
# 🔮 There will be 20 epochs, for around 1920 total training steps.
#
# 🏭 Installing trainer...
#
# 42 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# The following additional packages will be installed:
#   libaria2-0 libc-ares2 python3-pip-whl python3-setuptools-whl
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2 python3-pip-whl python3-setuptools-whl
#   python3.10-venv
# 0 upgraded, 6 newly installed, 0 to remove and 42 not upgraded.
# Need to get 3,991 kB of archives.
# After this operation, 8,189 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../0-libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../1-libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../2-aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Selecting previously unselected package python3-pip-whl.
# Preparing to unpack .../3-python3-pip-whl_22.0.2+dfsg-1ubuntu0.6_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../4-python3-setuptools-whl_68.1.2-2~jammy3_all.deb ...
# Unpacking python3-setuptools-whl (68.1.2-2~jammy3) ...
# Selecting previously unselected package python3.10-venv.
# Preparing to unpack .../5-python3.10-venv_3.10.12-1~22.04.10_amd64.deb ...
# Unpacking python3.10-venv (3.10.12-1~22.04.10) ...
# Setting up python3-setuptools-whl (68.1.2-2~jammy3) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.6) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up python3.10-venv (3.10.12-1~22.04.10) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Cloning into '/content/trainer'...
# remote: Enumerating objects: 388, done.
# remote: Counting objects: 100% (214/214), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 388 (delta 179), reused 145 (delta 145), pack-reused 174 (from 2)
# Receiving objects: 100% (388/388), 7.80 MiB | 11.05 MiB/s, done.
# Resolving deltas: 100% (221/221), done.
# HEAD is now at 47ef6ed added installer for linux python 3.12 added a log-like output of the warmup steps in the console
# Submodule 'sd_scripts' (https://github.com/kohya-ss/sd-scripts) registered for path 'sd_scripts'
# Cloning into '/content/trainer/sd_scripts'...
# Submodule path 'sd_scripts': checked out 'e89653975ddf429cdf0c0fd268da0a5a3e8dba1f'
# creating venv and installing requirements
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Collecting torch==2.5.1
#   Downloading https://download.pytorch.org/whl/cu124/torch-2.5.1%2Bcu124-cp310-cp310-linux_x86_64.whl (908.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 MB 1.1 MB/s eta 0:00:00
# Collecting torchvision==0.20.1
#   Downloading https://download.pytorch.org/whl/cu124/torchvision-0.20.1%2Bcu124-cp310-cp310-linux_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 99.2 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.4.5.8
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.4.127
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 KB 14.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.4.127
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.1 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12==12.4.127
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.1 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.5.147
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.6 MB/s eta 0:00:00
# Collecting filelock
#   Downloading https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting nvidia-nccl-cu12==2.21.5
#   Downloading https://download.pytorch.org/whl/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.7 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading https://download.pytorch.org/whl/Jinja2-3.1.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 KB 18.9 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.2.1.3
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.6.1.9
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.1 MB/s eta 0:00:00
# Collecting networkx
#   Downloading https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 64.0 MB/s eta 0:00:00
# Collecting typing-extensions>=4.8.0
#   Downloading https://download.pytorch.org/whl/typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.3.1.170
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.4.127
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 KB 76.3 MB/s eta 0:00:00
# Collecting fsspec
#   Downloading https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 KB 28.6 MB/s eta 0:00:00
# Collecting triton==3.1.0
#   Downloading https://download.pytorch.org/whl/triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 6.2 MB/s eta 0:00:00
# Collecting sympy==1.13.1
#   Downloading https://download.pytorch.org/whl/sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 88.0 MB/s eta 0:00:00
# Collecting numpy
#   Downloading https://download.pytorch.org/whl/numpy-2.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 60.8 MB/s eta 0:00:00
# Collecting pillow!=8.3.*,>=5.3.0
#   Downloading https://download.pytorch.org/whl/pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 96.4 MB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0
#   Downloading https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 51.9 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Downloading https://download.pytorch.org/whl/MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Installing collected packages: mpmath, typing-extensions, sympy, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchvision
# Successfully installed MarkupSafe-2.1.5 filelock-3.13.1 fsspec-2024.6.1 jinja2-3.1.4 mpmath-1.3.0 networkx-3.3 numpy-2.1.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 pillow-11.0.0 sympy-1.13.1 torch-2.5.1+cu124 torchvision-0.20.1+cu124 triton-3.1.0 typing-extensions-4.12.2
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Collecting xformers==0.0.29.post1
#   Downloading https://download.pytorch.org/whl/cu124/xformers-0.0.29.post1-cp310-cp310-manylinux_2_28_x86_64.whl (44.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 MB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: torch==2.5.1 in ./venv/lib/python3.10/site-packages (from xformers==0.0.29.post1) (2.5.1+cu124)
# Requirement already satisfied: numpy in ./venv/lib/python3.10/site-packages (from xformers==0.0.29.post1) (2.1.2)
# Requirement already satisfied: networkx in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (3.3)
# Requirement already satisfied: triton==3.1.0 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (3.1.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (11.6.1.9)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (12.4.5.8)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (4.12.2)
# Requirement already satisfied: sympy==1.13.1 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (1.13.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (12.4.127)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (3.1.4)
# Requirement already satisfied: fsspec in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (2024.6.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (10.3.5.147)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (9.1.0.70)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (12.3.1.170)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (12.4.127)
# Requirement already satisfied: filelock in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (3.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (12.4.127)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (2.21.5)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (11.2.1.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch==2.5.1->xformers==0.0.29.post1) (12.4.127)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.10/site-packages (from sympy==1.13.1->torch==2.5.1->xformers==0.0.29.post1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.10/site-packages (from jinja2->torch==2.5.1->xformers==0.0.29.post1) (2.1.5)
# Installing collected packages: xformers
# Successfully installed xformers-0.0.29.post1
# Obtaining file:///content/trainer/sd_scripts (from -r requirements.txt (line 45))
#   Preparing metadata (setup.py) ... done
# Collecting accelerate==0.33.0
#   Downloading accelerate-0.33.0-py3-none-any.whl (315 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.1/315.1 KB 6.0 MB/s eta 0:00:00
# Collecting transformers==4.44.0
#   Downloading transformers-4.44.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 26.8 MB/s eta 0:00:00
# Collecting diffusers[torch]==0.25.0
#   Downloading diffusers-0.25.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 50.5 MB/s eta 0:00:00
# Collecting ftfy==6.1.1
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 9.2 MB/s eta 0:00:00
# Collecting opencv-python==4.8.1.78
#   Downloading opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 10.8 MB/s eta 0:00:00
# Collecting einops==0.7.0
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 KB 4.8 MB/s eta 0:00:00
# Collecting pytorch-lightning==1.9.0
#   Downloading pytorch_lightning-1.9.0-py3-none-any.whl (825 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 KB 63.9 MB/s eta 0:00:00
# Collecting bitsandbytes==0.44.0
#   Downloading bitsandbytes-0.44.0-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 8.7 MB/s eta 0:00:00
# Collecting prodigyopt==1.0
#   Downloading prodigyopt-1.0-py3-none-any.whl (5.5 kB)
# Collecting lion-pytorch==0.0.6
#   Downloading lion_pytorch-0.0.6-py3-none-any.whl (4.2 kB)
# Collecting schedulefree==1.4
#   Downloading schedulefree-1.4.tar.gz (22 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tensorboard
#   Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 108.1 MB/s eta 0:00:00
# Collecting safetensors==0.4.4
#   Downloading safetensors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.5/435.5 KB 48.4 MB/s eta 0:00:00
# Collecting altair==4.2.2
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 KB 79.2 MB/s eta 0:00:00
# Collecting easygui==0.98.3
#   Downloading easygui-0.98.3-py2.py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 KB 13.6 MB/s eta 0:00:00
# Collecting toml==0.10.2
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting voluptuous==0.13.1
#   Downloading voluptuous-0.13.1-py3-none-any.whl (29 kB)
# Collecting huggingface-hub==0.24.5
#   Downloading huggingface_hub-0.24.5-py3-none-any.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 KB 52.0 MB/s eta 0:00:00
# Collecting imagesize==1.4.1
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Collecting rich==13.7.0
#   Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 KB 37.1 MB/s eta 0:00:00
# Collecting sentencepiece==0.2.0
#   Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 90.7 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.10.0 in ./venv/lib/python3.10/site-packages (from accelerate==0.33.0->-r requirements.txt (line 1)) (2.5.1+cu124)
# Collecting psutil
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 KB 36.2 MB/s eta 0:00:00
# Collecting numpy<2.0.0,>=1.17
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 56.6 MB/s eta 0:00:00
# Collecting packaging>=20.0
#   Downloading packaging-25.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 KB 12.0 MB/s eta 0:00:00
# Collecting pyyaml
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 KB 56.1 MB/s eta 0:00:00
# Collecting tqdm>=4.27
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 12.3 MB/s eta 0:00:00
# Collecting requests
#   Downloading requests-2.32.4-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 KB 7.4 MB/s eta 0:00:00
# Collecting tokenizers<0.20,>=0.19
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 93.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in ./venv/lib/python3.10/site-packages (from transformers==4.44.0->-r requirements.txt (line 2)) (3.13.1)
# Collecting regex!=2019.12.17
#   Downloading regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.7/781.7 KB 70.8 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in ./venv/lib/python3.10/site-packages (from diffusers[torch]==0.25.0->-r requirements.txt (line 3)) (11.0.0)
# Collecting importlib-metadata
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Collecting wcwidth>=0.2.5
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./venv/lib/python3.10/site-packages (from pytorch-lightning==1.9.0->-r requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: fsspec[http]>2021.06.0 in ./venv/lib/python3.10/site-packages (from pytorch-lightning==1.9.0->-r requirements.txt (line 8)) (2024.6.1)
# Collecting lightning-utilities>=0.4.2
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-1.7.4-py3-none-any.whl (963 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 KB 87.2 MB/s eta 0:00:00
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting pandas>=0.18
#   Downloading pandas-2.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 113.2 MB/s eta 0:00:00
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.24.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 KB 13.2 MB/s eta 0:00:00
# Collecting toolz
#   Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 KB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in ./venv/lib/python3.10/site-packages (from altair==4.2.2->-r requirements.txt (line 16)) (3.1.4)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 87.4 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 KB 15.6 MB/s eta 0:00:00
# Collecting absl-py>=0.4
#   Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 KB 27.6 MB/s eta 0:00:00
# Collecting protobuf!=4.24.0,>=3.19.6
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.1/321.1 KB 43.5 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 99.5 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 KB 35.6 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading markdown-3.8.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 KB 18.0 MB/s eta 0:00:00
# Collecting six>1.9
#   Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.73.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 92.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.0.0 in ./venv/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 13)) (68.1.2)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.12.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.0 MB/s eta 0:00:00
# Collecting attrs>=22.2.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 KB 10.4 MB/s eta 0:00:00
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (383 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.8/383.8 KB 47.1 MB/s eta 0:00:00
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.4.1-py3-none-any.whl (18 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 KB 34.9 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 KB 57.7 MB/s eta 0:00:00
# Collecting python-dateutil>=2.8.2
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 KB 38.4 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (12.4.5.8)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: networkx in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (12.3.1.170)
# Requirement already satisfied: triton==3.1.0 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (11.2.1.3)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (9.1.0.70)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (2.21.5)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (11.6.1.9)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.10.0->accelerate==0.33.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 13)) (2.1.5)
# Collecting zipp>=3.20
#   Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.5/149.5 KB 22.3 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 KB 20.6 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 KB 10.0 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.7.9-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.2/159.2 KB 26.7 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.6.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.6/241.6 KB 33.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.4.0
#   Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.1/326.1 KB 42.4 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.7.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.9/222.9 KB 29.5 MB/s eta 0:00:00
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting aiohappyeyeballs>=2.5.0
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.3/198.3 KB 30.1 MB/s eta 0:00:00
# Building wheels for collected packages: schedulefree
#   Building wheel for schedulefree (pyproject.toml) ... done
#   Created wheel for schedulefree: filename=schedulefree-1.4-py3-none-any.whl size=39334 sha256=5a9c5442d855e8bc6d6293cfeaa39be7ec299804bdcfea35ee3fe4b94228b562
#   Stored in directory: /root/.cache/pip/wheels/04/4f/8e/15e0ac6c13041e94078d9e4f88d14c2cd00ec198bc0fc78e91
# Successfully built schedulefree
# Installing collected packages: wcwidth, voluptuous, sentencepiece, pytz, library, easygui, zipp, werkzeug, urllib3, tzdata, tqdm, toolz, toml, tensorboard-data-server, six, schedulefree, safetensors, rpds-py, regex, pyyaml, pygments, psutil, protobuf, propcache, prodigyopt, packaging, numpy, multidict, mdurl, markdown, imagesize, idna, grpcio, ftfy, frozenlist, entrypoints, einops, charset_normalizer, certifi, attrs, async-timeout, aiohappyeyeballs, absl-py, yarl, tensorboard, requests, referencing, python-dateutil, opencv-python, markdown-it-py, lightning-utilities, importlib-metadata, aiosignal, rich, pandas, jsonschema-specifications, huggingface-hub, aiohttp, torchmetrics, tokenizers, lion-pytorch, jsonschema, diffusers, bitsandbytes, accelerate, transformers, pytorch-lightning, altair
#   Running setup.py develop for library
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.2
#     Uninstalling numpy-2.1.2:
#       Successfully uninstalled numpy-2.1.2
# Successfully installed absl-py-2.3.1 accelerate-0.33.0 aiohappyeyeballs-2.6.1 aiohttp-3.12.14 aiosignal-1.4.0 altair-4.2.2 async-timeout-5.0.1 attrs-25.3.0 bitsandbytes-0.44.0 certifi-2025.7.9 charset_normalizer-3.4.2 diffusers-0.25.0 easygui-0.98.3 einops-0.7.0 entrypoints-0.4 frozenlist-1.7.0 ftfy-6.1.1 grpcio-1.73.1 huggingface-hub-0.24.5 idna-3.10 imagesize-1.4.1 importlib-metadata-8.7.0 jsonschema-4.24.0 jsonschema-specifications-2025.4.1 library-0.0.0 lightning-utilities-0.14.3 lion-pytorch-0.0.6 markdown-3.8.2 markdown-it-py-3.0.0 mdurl-0.1.2 multidict-6.6.3 numpy-1.26.4 opencv-python-4.8.1.78 packaging-25.0 pandas-2.3.1 prodigyopt-1.0 propcache-0.3.2 protobuf-6.31.1 psutil-7.0.0 pygments-2.19.2 python-dateutil-2.9.0.post0 pytorch-lightning-1.9.0 pytz-2025.2 pyyaml-6.0.2 referencing-0.36.2 regex-2024.11.6 requests-2.32.4 rich-13.7.0 rpds-py-0.26.0 safetensors-0.4.4 schedulefree-1.4 sentencepiece-0.2.0 six-1.17.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tokenizers-0.19.1 toml-0.10.2 toolz-1.0.0 torchmetrics-1.7.4 tqdm-4.67.1 transformers-4.44.0 tzdata-2025.2 urllib3-2.5.0 voluptuous-0.13.1 wcwidth-0.2.13 werkzeug-3.1.3 yarl-1.20.1 zipp-3.23.0
# Processing /content/trainer/custom_scheduler
#   Preparing metadata (setup.py) ... done
# Using legacy 'setup.py install' for LoraEasyCustomOptimizer, since package 'wheel' is not installed.
# Installing collected packages: LoraEasyCustomOptimizer
#   Running setup.py install for LoraEasyCustomOptimizer ... done
# Successfully installed LoraEasyCustomOptimizer-1.0.0
# Collecting starlette
#   Downloading starlette-0.47.1-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 KB 3.1 MB/s eta 0:00:00
# Collecting uvicorn[standard]
#   Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 KB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in ./venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 3)) (2.32.4)
# Collecting dadaptation
#   Downloading dadaptation-3.2.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting wandb
#   Downloading wandb-0.21.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 67.1 MB/s eta 0:00:00
# Collecting pyngrok
#   Downloading pyngrok-7.2.12-py3-none-any.whl (26 kB)
# Collecting pycloudflared
#   Downloading pycloudflared-0.2.0-py3-none-any.whl (7.3 kB)
# Collecting scipy
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 14.2 MB/s eta 0:00:00
# Collecting came-pytorch
#   Downloading came_pytorch-0.1.3-py3-none-any.whl (6.2 kB)
# Collecting lycoris-lora==3.0.1.dev10
#   Downloading lycoris_lora-3.0.1.dev10.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 KB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pytorch_optimizer==3.1.2
#   Downloading pytorch_optimizer-3.1.2-py3-none-any.whl (187 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 KB 29.3 MB/s eta 0:00:00
# Collecting wheel
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Requirement already satisfied: einops in ./venv/lib/python3.10/site-packages (from lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: toml in ./venv/lib/python3.10/site-packages (from lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (0.10.2)
# Requirement already satisfied: torch in ./venv/lib/python3.10/site-packages (from lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (2.5.1+cu124)
# Requirement already satisfied: tqdm in ./venv/lib/python3.10/site-packages (from lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (4.67.1)
# Requirement already satisfied: numpy in ./venv/lib/python3.10/site-packages (from pytorch_optimizer==3.1.2->-r ../requirements.txt (line 11)) (1.26.4)
# Collecting anyio<5,>=3.6.2
#   Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 KB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv/lib/python3.10/site-packages (from starlette->-r ../requirements.txt (line 1)) (4.12.2)
# Collecting h11>=0.8
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting click>=7.0
#   Downloading click-8.2.1-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 KB 18.8 MB/s eta 0:00:00
# Collecting uvloop>=0.15.1
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 104.7 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Collecting httptools>=0.6.3
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 KB 47.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in ./venv/lib/python3.10/site-packages (from uvicorn[standard]->-r ../requirements.txt (line 2)) (6.0.2)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (453 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 KB 56.9 MB/s eta 0:00:00
# Collecting websockets>=10.4
#   Downloading websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 KB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.10/site-packages (from requests->-r ../requirements.txt (line 3)) (2025.7.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.10/site-packages (from requests->-r ../requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.10/site-packages (from requests->-r ../requirements.txt (line 3)) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.10/site-packages (from requests->-r ../requirements.txt (line 3)) (3.4.2)
# Collecting platformdirs
#   Downloading platformdirs-4.3.8-py3-none-any.whl (18 kB)
# Collecting pydantic<3
#   Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 KB 45.0 MB/s eta 0:00:00
# Collecting sentry-sdk>=2.0.0
#   Downloading sentry_sdk-2.32.0-py2.py3-none-any.whl (356 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.1/356.1 KB 44.7 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in ./venv/lib/python3.10/site-packages (from wandb->-r ../requirements.txt (line 5)) (6.31.1)
# Requirement already satisfied: packaging in ./venv/lib/python3.10/site-packages (from wandb->-r ../requirements.txt (line 5)) (25.0)
# Collecting gitpython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 KB 32.4 MB/s eta 0:00:00
# Collecting tomli
#   Downloading tomli-2.2.1-py3-none-any.whl (14 kB)
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 8.5 MB/s eta 0:00:00
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 88.5 MB/s eta 0:00:00
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (11.2.1.3)
# Requirement already satisfied: triton==3.1.0 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (3.1.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (2.21.5)
# Requirement already satisfied: networkx in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (3.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (12.4.127)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (12.4.5.8)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (9.1.0.70)
# Requirement already satisfied: fsspec in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (2024.6.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (12.3.1.170)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (12.4.127)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (10.3.5.147)
# Requirement already satisfied: sympy==1.13.1 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (1.13.1)
# Requirement already satisfied: filelock in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (3.13.1)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (3.1.4)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (11.6.1.9)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (12.4.127)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.10/site-packages (from sympy==1.13.1->torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (1.3.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.10/site-packages (from jinja2->torch->lycoris-lora==3.0.1.dev10->-r ../requirements.txt (line 10)) (2.1.5)
# Using legacy 'setup.py install' for lycoris-lora, since package 'wheel' is not installed.
# Building wheels for collected packages: dadaptation
#   Building wheel for dadaptation (pyproject.toml) ... done
#   Created wheel for dadaptation: filename=dadaptation-3.2-py3-none-any.whl size=23290 sha256=03153f6b9543f3c40327277cbd2a30374d0cbed5e144197d315d3bdf3456cc8c
#   Stored in directory: /root/.cache/pip/wheels/d0/03/6d/feba04df15ef39d9ac4e3504058ac2a88fb2ef9183ba92b111
# Successfully built dadaptation
# Installing collected packages: wheel, websockets, uvloop, typing-inspection, tomli, sniffio, smmap, sentry-sdk, scipy, python-dotenv, pyngrok, pydantic-core, platformdirs, httptools, h11, exceptiongroup, dadaptation, click, annotated-types, uvicorn, pydantic, pycloudflared, gitdb, anyio, watchfiles, starlette, gitpython, wandb, pytorch_optimizer, lycoris-lora, came-pytorch
#   Running setup.py install for lycoris-lora ... done
# Successfully installed annotated-types-0.7.0 anyio-4.9.0 came-pytorch-0.1.3 click-8.2.1 dadaptation-3.2 exceptiongroup-1.3.0 gitdb-4.0.12 gitpython-3.1.44 h11-0.16.0 httptools-0.6.4 lycoris-lora-3.0.1.dev10 platformdirs-4.3.8 pycloudflared-0.2.0 pydantic-2.11.7 pydantic-core-2.33.2 pyngrok-7.2.12 python-dotenv-1.1.1 pytorch_optimizer-3.1.2 scipy-1.15.3 sentry-sdk-2.32.0 smmap-5.0.2 sniffio-1.3.1 starlette-0.47.1 tomli-2.2.1 typing-inspection-0.4.1 uvicorn-0.35.0 uvloop-0.21.0 wandb-0.21.0 watchfiles-1.1.0 websockets-15.0.1 wheel-0.45.1
# completed installing
# Found existing installation: rich 13.7.0
# Uninstalling rich-13.7.0:
#   Successfully uninstalled rich-13.7.0
#
# ✅ Installation finished in 310 seconds.
#
# 🔄 Getting model...
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e7704b|OK  |   141MiB/s|//content/NoobAI-XL-v1.1.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 57345f|OK  |   266MiB/s|//content/sdxl_vae.safetensors
#
# Status Legend:
# (OK):download completed.
#
#
# 📄 Config saved to /content/drive/MyDrive/Loras/cecily_noein/training_config.toml
# 📄 Dataset config saved to /content/drive/MyDrive/Loras/cecily_noein/dataset_config.toml
#
# ⭐ Starting trainer...
#
# rich is not installed, using basic logging
# Loading settings from /content/drive/MyDrive/Loras/cecily_noein/training_config.toml...
# /content/drive/MyDrive/Loras/cecily_noein/training_config
# rich is not installed, using basic logging
# tokenizer_config.json: 100% 905/905 [00:00<00:00, 4.64MB/s]
# vocab.json: 961kB [00:00, 5.31MB/s]
# merges.txt: 525kB [00:00, 22.9MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 2.08MB/s]
# tokenizer.json: 2.22MB [00:00, 38.7MB/s]
# tokenizer_config.json: 100% 904/904 [00:00<00:00, 7.14MB/s]
# vocab.json: 862kB [00:00, 63.5MB/s]
# merges.txt: 525kB [00:00, 57.2MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 3.32MB/s]
# tokenizer.json: 2.22MB [00:00, 96.8MB/s]
# Loading dataset config from /content/drive/MyDrive/Loras/cecily_noein/dataset_config.toml
# prepare images.
# get image size from name of cache files
# 100% 73/73 [00:00<00:00, 499484.82it/s]
# set image size from cache files: 0/73
# found directory /content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_cg contains 73 image files
# read caption: 100% 73/73 [00:01<00:00, 39.51it/s]
# get image size from name of cache files
# 100% 100/100 [00:00<00:00, 313241.52it/s]
# set image size from cache files: 0/100
# found directory /content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_manga contains 100 image files
# read caption: 100% 100/100 [00:02<00:00, 42.50it/s]
# get image size from name of cache files
# 100% 45/45 [00:00<00:00, 436906.67it/s]
# set image size from cache files: 0/45
# found directory /content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_portrait contains 45 image files
# read caption: 100% 45/45 [00:12<00:00,  3.55it/s]
# get image size from name of cache files
# 100% 52/52 [00:00<00:00, 330961.77it/s]
# set image size from cache files: 0/52
# found directory /content/drive/MyDrive/Loras/cecily_noein/dataset/noein contains 52 image files
# read caption: 100% 52/52 [00:01<00:00, 33.85it/s]
# get image size from name of cache files
# 100% 47/47 [00:00<00:00, 295550.66it/s]
# set image size from cache files: 0/47
# found directory /content/drive/MyDrive/Loras/cecily_noein/dataset/noein_manga contains 47 image files
# read caption: 100% 47/47 [00:13<00:00,  3.37it/s]
# get image size from name of cache files
# 100% 6/6 [00:00<00:00, 105738.76it/s]
# set image size from cache files: 0/6
# found directory /content/drive/MyDrive/Loras/cecily_noein/dataset/bundus contains 6 image files
# read caption: 100% 6/6 [00:01<00:00,  3.95it/s]
# get image size from name of cache files
# 100% 20/20 [00:00<00:00, 215645.45it/s]
# set image size from cache files: 0/20
# found directory /content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_noein contains 20 image files
# read caption: 100% 20/20 [00:06<00:00,  3.33it/s]
# get image size from name of cache files
# 100% 36/36 [00:00<00:00, 302595.08it/s]
# set image size from cache files: 0/36
# found directory /content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_noein_manga contains 36 image files
# read caption: 100% 36/36 [00:10<00:00,  3.43it/s]
# get image size from name of cache files
# 100% 5/5 [00:00<00:00, 84904.94it/s]
# set image size from cache files: 0/5
# found directory /content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_bundus contains 5 image files
# read caption: 100% 5/5 [00:01<00:00,  3.55it/s]
# 384 train images with repeating.
# 0 reg images.
# no regularization images / 正則化画像が見つかりませんでした
# [Dataset 0]
#   batch_size: 4
#   resolution: (1024, 1024)
#   enable_bucket: True
#   network_multiplier: 1.0
#   min_bucket_reso: 256
#   max_bucket_reso: 4096
#   bucket_reso_steps: 64
#   bucket_no_upscale: False
#
#   [Subset 0 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_cg"
#     image_count: 73
#     num_repeats: 1
#     shuffle_caption: True
#     keep_tokens: 1
#     keep_tokens_separator:
#     caption_separator: ,
#     secondary_separator: None
#     enable_wildcard: False
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epochs: 0
#     caption_tag_dropout_rate: 0.0
#     caption_prefix: None
#     caption_suffix: None
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1
#     token_warmup_step: 0
#     alpha_mask: False
#     custom_attributes: {}
#     is_reg: False
#     class_tokens: None
#     caption_extension: .txt
#
#   [Subset 1 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_manga"
#     image_count: 100
#     num_repeats: 1
#     shuffle_caption: True
#     keep_tokens: 1
#     keep_tokens_separator:
#     caption_separator: ,
#     secondary_separator: None
#     enable_wildcard: False
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epochs: 0
#     caption_tag_dropout_rate: 0.0
#     caption_prefix: None
#     caption_suffix: None
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1
#     token_warmup_step: 0
#     alpha_mask: False
#     custom_attributes: {}
#     is_reg: False
#     class_tokens: None
#     caption_extension: .txt
#
#   [Subset 2 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_portrait"
#     image_count: 45
#     num_repeats: 1
#     shuffle_caption: True
#     keep_tokens: 1
#     keep_tokens_separator:
#     caption_separator: ,
#     secondary_separator: None
#     enable_wildcard: False
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epochs: 0
#     caption_tag_dropout_rate: 0.0
#     caption_prefix: None
#     caption_suffix: None
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1
#     token_warmup_step: 0
#     alpha_mask: False
#     custom_attributes: {}
#     is_reg: False
#     class_tokens: None
#     caption_extension: .txt
#
#   [Subset 3 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/Loras/cecily_noein/dataset/noein"
#     image_count: 52
#     num_repeats: 1
#     shuffle_caption: True
#     keep_tokens: 1
#     keep_tokens_separator:
#     caption_separator: ,
#     secondary_separator: None
#     enable_wildcard: False
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epochs: 0
#     caption_tag_dropout_rate: 0.0
#     caption_prefix: None
#     caption_suffix: None
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1
#     token_warmup_step: 0
#     alpha_mask: False
#     custom_attributes: {}
#     is_reg: False
#     class_tokens: None
#     caption_extension: .txt
#
#   [Subset 4 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/Loras/cecily_noein/dataset/noein_manga"
#     image_count: 47
#     num_repeats: 1
#     shuffle_caption: True
#     keep_tokens: 1
#     keep_tokens_separator:
#     caption_separator: ,
#     secondary_separator: None
#     enable_wildcard: False
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epochs: 0
#     caption_tag_dropout_rate: 0.0
#     caption_prefix: None
#     caption_suffix: None
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1
#     token_warmup_step: 0
#     alpha_mask: False
#     custom_attributes: {}
#     is_reg: False
#     class_tokens: None
#     caption_extension: .txt
#
#   [Subset 5 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus"
#     image_count: 6
#     num_repeats: 1
#     shuffle_caption: True
#     keep_tokens: 1
#     keep_tokens_separator:
#     caption_separator: ,
#     secondary_separator: None
#     enable_wildcard: False
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epochs: 0
#     caption_tag_dropout_rate: 0.0
#     caption_prefix: None
#     caption_suffix: None
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1
#     token_warmup_step: 0
#     alpha_mask: False
#     custom_attributes: {}
#     is_reg: False
#     class_tokens: None
#     caption_extension: .txt
#
#   [Subset 6 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_noein"
#     image_count: 20
#     num_repeats: 1
#     shuffle_caption: True
#     keep_tokens: 2
#     keep_tokens_separator:
#     caption_separator: ,
#     secondary_separator: None
#     enable_wildcard: False
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epochs: 0
#     caption_tag_dropout_rate: 0.0
#     caption_prefix: None
#     caption_suffix: None
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1
#     token_warmup_step: 0
#     alpha_mask: False
#     custom_attributes: {}
#     is_reg: False
#     class_tokens: None
#     caption_extension: .txt
#
#   [Subset 7 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_noein_manga"
#     image_count: 36
#     num_repeats: 1
#     shuffle_caption: True
#     keep_tokens: 2
#     keep_tokens_separator:
#     caption_separator: ,
#     secondary_separator: None
#     enable_wildcard: False
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epochs: 0
#     caption_tag_dropout_rate: 0.0
#     caption_prefix: None
#     caption_suffix: None
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1
#     token_warmup_step: 0
#     alpha_mask: False
#     custom_attributes: {}
#     is_reg: False
#     class_tokens: None
#     caption_extension: .txt
#
#   [Subset 8 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_bundus"
#     image_count: 5
#     num_repeats: 1
#     shuffle_caption: True
#     keep_tokens: 2
#     keep_tokens_separator:
#     caption_separator: ,
#     secondary_separator: None
#     enable_wildcard: False
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epochs: 0
#     caption_tag_dropout_rate: 0.0
#     caption_prefix: None
#     caption_suffix: None
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1
#     token_warmup_step: 0
#     alpha_mask: False
#     custom_attributes: {}
#     is_reg: False
#     class_tokens: None
#     caption_extension: .txt
#
#
# [Dataset 0]
# loading image sizes.
# 100% 384/384 [00:58<00:00,  6.57it/s]
# make buckets
# number of images (including repeats) / 各bucketの画像枚数（繰り返し回数を含む）
# bucket 0: resolution (704, 1408), count: 2
# bucket 1: resolution (768, 1280), count: 9
# bucket 2: resolution (768, 1344), count: 11
# bucket 3: resolution (832, 1216), count: 43
# bucket 4: resolution (896, 1152), count: 57
# bucket 5: resolution (960, 1088), count: 78
# bucket 6: resolution (1024, 1024), count: 53
# bucket 7: resolution (1088, 960), count: 47
# bucket 8: resolution (1152, 896), count: 29
# bucket 9: resolution (1216, 832), count: 23
# bucket 10: resolution (1280, 768), count: 4
# bucket 11: resolution (1344, 768), count: 28
# mean ar error (without repeats): 0.028545507427900563
# preparing accelerator
# accelerator device: cuda
# loading model for process 0/1
# load StableDiffusion checkpoint: /content/NoobAI-XL-v1.1.safetensors
# building U-Net
# loading U-Net from checkpoint
# U-Net: <All keys matched successfully>
# building text encoders
# loading text encoders from checkpoint
# text encoder 1: <All keys matched successfully>
# text encoder 2: <All keys matched successfully>
# building VAE
# loading VAE from checkpoint
# VAE: <All keys matched successfully>
# load VAE: /content/sdxl_vae.safetensors
# additional VAE loaded
# Enable SDPA for U-Net
# import network module: networks.lora
# [Dataset 0]
# caching latents with caching strategy.
# caching latents...
#  19% 72/384 [01:52<08:46,  1.69s/it]

# %% [markdown]
# ## *️⃣ Extras
#
# You can run these before starting the training.

# %%
# prompt: remove all .ipynb_checkpoints files in the given folder and subfolder

import shutil

def remove_ipynb_checkpoints(folder_path):
    for root, dirs, files in os.walk(folder_path):
        if '.ipynb_checkpoints' in dirs:
            checkpoints_path = os.path.join(root, '.ipynb_checkpoints')
            print(f"Removing: {checkpoints_path}")
            shutil.rmtree(checkpoints_path)

# Specify the folder path you want to clean
# For example, to clean the current directory and its subfolders:
# remove_ipynb_checkpoints('.')

# To clean a specific folder in Google Drive:
# remove_ipynb_checkpoints('/content/drive/MyDrive/your_folder_name')

# Replace the placeholder below with the actual folder you want to clean
# For example, using the main_dir variable from the preceding code:
if 'main_dir' in globals():
    remove_ipynb_checkpoints(main_dir)
else:
    print("Please define the folder path to clean.")
    # As a fallback, you might want to define a default path or ask the user for input.
    # Example default: remove_ipynb_checkpoints('/content/drive/MyDrive')
    pass
# Out:
# Removing: /content/drive/MyDrive/Loras/cecily_noein/.ipynb_checkpoints
# Removing: /content/drive/MyDrive/Loras/cecily_noein/dataset/.ipynb_checkpoints
# Removing: /content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_noein/.ipynb_checkpoints
# Removing: /content/drive/MyDrive/Loras/cecily_noein/dataset/noein/.ipynb_checkpoints

# %%
# prompt: read in image files and txt files from a given folder recursively. The images and texts should be paired together by same names. Assign a unique name to each such pairs and replace the original names. The unique name should follow the pattern folder name + index

import os
from PIL import Image

def rename_files_recursively(folder_path):
    """
    Reads image and text files from a given folder recursively, pairs them by name,
    assigns a unique name to each pair, and replaces the original names.

    Args:
        folder_path (str): The path to the folder to process.
    """
    pairs = {}
    for root, _, files in os.walk(folder_path):
        for file in files:
            name, ext = os.path.splitext(file)
            full_path = os.path.join(root, file)
            if ext.lower() in ['.jpg', '.jpeg', '.png', '.webp', '.bmp', '.txt', '.caption']:
                if name not in pairs:
                    pairs[name] = {}
                if ext.lower() in ['.jpg', '.jpeg', '.png', '.webp', '.bmp']:
                    pairs[name]['image'] = full_path
                elif ext.lower() in ['.txt', '.caption']:
                    pairs[name]['text'] = full_path

    folder_name = os.path.basename(os.path.normpath(folder_path))
    index = 0
    for name, files in pairs.items():
        if 'image' in files and 'text' in files:
            new_name_base = f"{folder_name}_{index:04d}"
            new_image_path = os.path.join(os.path.dirname(files['image']), new_name_base + os.path.splitext(files['image'])[1])
            new_text_path = os.path.join(os.path.dirname(files['text']), new_name_base + os.path.splitext(files['text'])[1])

            # Rename files
            os.rename(files['image'], new_image_path)
            os.rename(files['text'], new_text_path)

            print(f"Renamed '{files['image']}' to '{new_image_path}'")
            print(f"Renamed '{files['text']}' to '{new_text_path}'")

            index += 1
        elif 'image' in files:
            print(f"Warning: Image file '{files['image']}' has no matching text file.")
        elif 'text' in files:
            print(f"Warning: Text file '{files['text']}' has no matching image file.")

# Example usage: Replace 'images_folder' with the actual variable holding your image folder path
# Ensure 'images_folder' is defined and points to the correct directory from the preceding code
rename_files_recursively(images_folder)
# Out:
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/b0ddfcc6611b4e32971da9e95d0054da.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0000.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/b0ddfcc6611b4e32971da9e95d0054da.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0000.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/82b327a1238041a093aecde1c05981e3.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0001.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/82b327a1238041a093aecde1c05981e3.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0001.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/861d32c3267f4241aa0c62f0b1183503.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0002.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/861d32c3267f4241aa0c62f0b1183503.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0002.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/52e16b7414fe46b19209ba86fec0568a.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0003.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/52e16b7414fe46b19209ba86fec0568a.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0003.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/ee686fa4bce84d44b729de61320ef8c6.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0004.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/ee686fa4bce84d44b729de61320ef8c6.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0004.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/fce3f5fd1afa415f8d7ce2a9da7c2b6f.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0005.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/fce3f5fd1afa415f8d7ce2a9da7c2b6f.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus/dataset_0005.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/faceaa630b5f4ea288ae1f3e12032ea1.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0006.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/faceaa630b5f4ea288ae1f3e12032ea1.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0006.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/0e40d4dea7cf437ea8a140f7b4b9348f.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0007.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/0e40d4dea7cf437ea8a140f7b4b9348f.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0007.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/bb7b0b18a77e49119c315b90f4be3720.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0008.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/bb7b0b18a77e49119c315b90f4be3720.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0008.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/4aaafe50fb014b23ae4d3add59f71f41.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0009.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/4aaafe50fb014b23ae4d3add59f71f41.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0009.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/d43670df59aa45ef8bf1b9de73a590e8.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0010.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/d43670df59aa45ef8bf1b9de73a590e8.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0010.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/68dfb4f1dc5b48339ff26378c8846f7b.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0011.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/68dfb4f1dc5b48339ff26378c8846f7b.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0011.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/a195007d40e1475782b4cdb27ba78e5d.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0012.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/a195007d40e1475782b4cdb27ba78e5d.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0012.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/9cac1e74689040a1a306ec7ef64d1264.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0013.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/9cac1e74689040a1a306ec7ef64d1264.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0013.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/b035d5a6047d43b7828230bdfc5a5f1f.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0014.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/b035d5a6047d43b7828230bdfc5a5f1f.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0014.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/a45e7277c35b41b88817fb5765d95642.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0015.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/a45e7277c35b41b88817fb5765d95642.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0015.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/64558233873240ea999865043969c718.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0016.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/64558233873240ea999865043969c718.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0016.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/765c51bfe09146c184a4367666006f41.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0017.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/765c51bfe09146c184a4367666006f41.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0017.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/5b6bafbf49ff4b15b54961804406dfcf.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0018.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/5b6bafbf49ff4b15b54961804406dfcf.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0018.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/a25014206fc044a6ade14c2179e4dbc0.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0019.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/a25014206fc044a6ade14c2179e4dbc0.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0019.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/3bc354ff78bb482d90badd7de5acd0e3.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0020.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/3bc354ff78bb482d90badd7de5acd0e3.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0020.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/3a285b9ca7b546a8a9182e40af365689.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0021.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/3a285b9ca7b546a8a9182e40af365689.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0021.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/27c6d93120944f618a6fc3c89b86145b.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0022.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/27c6d93120944f618a6fc3c89b86145b.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0022.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/9b3613d7014d414d976d3339b0b843dc.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0023.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/9b3613d7014d414d976d3339b0b843dc.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0023.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/d1d5d03a3f9441d99257d5a3c0f2c1d2.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0024.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/d1d5d03a3f9441d99257d5a3c0f2c1d2.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0024.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/b366034754924dc399c30f61ea62f07a.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0025.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/b366034754924dc399c30f61ea62f07a.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0025.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/28890285318f40bea6eb684675a8299a.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0026.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/28890285318f40bea6eb684675a8299a.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0026.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/38827d1dde4a465a92584b6d1d066613.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0027.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/38827d1dde4a465a92584b6d1d066613.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0027.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/81b1028953bd4721ba0b2917333088e6.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0028.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/81b1028953bd4721ba0b2917333088e6.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0028.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/f67092930ea54c0b9434837a3a6df9c3.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0029.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/f67092930ea54c0b9434837a3a6df9c3.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0029.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/3671092b32cd454ab82db6e7014cedeb.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0030.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/3671092b32cd454ab82db6e7014cedeb.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0030.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/8c6f7b4811e5475587527e5a67e16b50.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0031.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/8c6f7b4811e5475587527e5a67e16b50.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0031.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/133cae8b77064da58b41c62a8812f2c0.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0032.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/133cae8b77064da58b41c62a8812f2c0.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0032.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/4659d83f491045dc8a8ad361c8df09b8.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0033.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/4659d83f491045dc8a8ad361c8df09b8.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0033.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/b49c2b6788b046b28453bb012ffdd82e.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0034.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/b49c2b6788b046b28453bb012ffdd82e.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0034.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dbf8eaaa41244cdcadfebd7c301c5a93.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0035.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dbf8eaaa41244cdcadfebd7c301c5a93.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0035.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/fa4f1eeb518a44e79afd87c33d00eba8.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0036.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/fa4f1eeb518a44e79afd87c33d00eba8.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0036.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/99962207cb3944f68ee5c76b283b4f28.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0037.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/99962207cb3944f68ee5c76b283b4f28.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0037.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/80a0399e59b6400fab8649497771f85e.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0038.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/80a0399e59b6400fab8649497771f85e.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0038.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/3a3748bfc0dd4eb8866b32d337e5c6cd.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0039.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/3a3748bfc0dd4eb8866b32d337e5c6cd.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0039.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/e9125a4acf2740c09e325d5e610966fd.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0040.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/e9125a4acf2740c09e325d5e610966fd.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0040.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/52ba790f8a6d44c7863f04caba2f5eb2.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0041.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/52ba790f8a6d44c7863f04caba2f5eb2.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0041.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dac53e8150db4198b17dd59c80eb2f24.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0042.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dac53e8150db4198b17dd59c80eb2f24.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0042.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/2480c5dd1c7c4376a27f055b947bd163.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0043.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/2480c5dd1c7c4376a27f055b947bd163.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0043.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/bb9c5444a8be43419af67edeae3a5c28.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0044.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/bb9c5444a8be43419af67edeae3a5c28.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0044.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/1aa219ba15464b7596839aa54c8e7c4e.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0045.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/1aa219ba15464b7596839aa54c8e7c4e.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0045.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/91da8b1bda6749bca48beb373e08d076.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0046.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/91da8b1bda6749bca48beb373e08d076.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0046.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/e426c91dee4b4165b09e0cafa2b81930.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0047.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/e426c91dee4b4165b09e0cafa2b81930.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0047.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/9f9c9bebd6154be8ae761672a2650d81.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0048.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/9f9c9bebd6154be8ae761672a2650d81.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0048.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/77bc5eee10da4016bb531f4f33cb2f1b.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0049.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/77bc5eee10da4016bb531f4f33cb2f1b.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0049.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/087e973a1e5f42daae637dae283825e2.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0050.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/087e973a1e5f42daae637dae283825e2.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0050.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/0af9722e8c5f44cc8ad6291bab32f3dc.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0051.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/0af9722e8c5f44cc8ad6291bab32f3dc.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0051.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/87b22fac9df744b395e6a213e048a32d.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0052.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/87b22fac9df744b395e6a213e048a32d.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0052.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/ecdff77402264906891ee3e27a0c44f5.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0053.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/ecdff77402264906891ee3e27a0c44f5.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0053.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/7d005308d87d4669a0b211c98e016f2a.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0054.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/7d005308d87d4669a0b211c98e016f2a.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0054.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/8408a92f4a814d98b98fd243d8bdbc42.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0055.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/8408a92f4a814d98b98fd243d8bdbc42.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0055.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/71063dbd747e473ab31eb9b91c9332fc.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0056.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/71063dbd747e473ab31eb9b91c9332fc.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0056.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/f72c8a46f8a944689e0ec651e1c73e4e.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0057.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/f72c8a46f8a944689e0ec651e1c73e4e.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0057.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/b7b5389d6125412985001a0eb3e73d84.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0058.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/b7b5389d6125412985001a0eb3e73d84.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0058.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/c3a9de8b773c43bb9b5a6bcd4f2ba31d.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0059.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/c3a9de8b773c43bb9b5a6bcd4f2ba31d.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0059.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/644eca9505c0458eb062b3ad7cd5080f.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0060.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/644eca9505c0458eb062b3ad7cd5080f.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0060.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/a0aeabfd12f440b98d501fed3d98b371.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0061.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/a0aeabfd12f440b98d501fed3d98b371.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0061.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/1038390cf25b40589ff90f98d8da5824.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0062.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/1038390cf25b40589ff90f98d8da5824.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0062.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/18ed0ed4b7b347c8aa2aaa214b6c9dee.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0063.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/18ed0ed4b7b347c8aa2aaa214b6c9dee.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0063.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/a226813276b543b199bd97c4bec7dd2a.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0064.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/a226813276b543b199bd97c4bec7dd2a.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0064.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/7ea1479b3c6843d499fb2e72a4332595.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0065.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/7ea1479b3c6843d499fb2e72a4332595.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0065.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/45de876213a649e1aaf2eece2d71de87.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0066.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/45de876213a649e1aaf2eece2d71de87.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0066.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/254befeccc234badbe041ffc70237899.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0067.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/254befeccc234badbe041ffc70237899.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0067.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/59f43bf8aa1d4017bf3dd12cfdb06c51.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0068.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/59f43bf8aa1d4017bf3dd12cfdb06c51.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0068.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/e2af50f20602435da48f863a9ea7257e.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0069.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/e2af50f20602435da48f863a9ea7257e.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0069.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/7a415547774d4289a3e24319e1a1a79b.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0070.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/7a415547774d4289a3e24319e1a1a79b.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0070.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/412d5151515147b0990af78e0f928ffb.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0071.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/412d5151515147b0990af78e0f928ffb.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0071.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/1123c15e711b46359eafb7e0b440bd58.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0072.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/1123c15e711b46359eafb7e0b440bd58.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0072.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/5004fe2eb8084a41bcdbcdb633cc2758.png' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0073.png'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/5004fe2eb8084a41bcdbcdb633cc2758.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0073.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/f61c0cbf3c0f45fb92e37f77c19aa695.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0074.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/f61c0cbf3c0f45fb92e37f77c19aa695.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0074.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/6c313cc3c7cf4d3184cbb05f2c977abc.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0075.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/6c313cc3c7cf4d3184cbb05f2c977abc.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0075.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/28e508ee95b942d4bad61a0d7343c58e.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0076.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/28e508ee95b942d4bad61a0d7343c58e.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0076.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/2c5a1431d5504ad4a55aa005ce56a384.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0077.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/2c5a1431d5504ad4a55aa005ce56a384.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0077.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/b2cfa46a6e264277b88286d64d92d633.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0078.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/b2cfa46a6e264277b88286d64d92d633.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_cg/dataset_0078.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/49d02e2e78964aa588fbc36153c08872.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0079.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/49d02e2e78964aa588fbc36153c08872.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0079.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/cce06d2ab74b47e4a5171632d45ce62d.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0080.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/cce06d2ab74b47e4a5171632d45ce62d.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0080.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/c881edc012dd46acbe0725b18a6ba58b.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0081.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/c881edc012dd46acbe0725b18a6ba58b.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0081.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/0ba318d752b4487eb19dd6e6e8ce3c34.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0082.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/0ba318d752b4487eb19dd6e6e8ce3c34.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0082.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/041c9dabac604593a0ed8766fb06a242.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0083.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/041c9dabac604593a0ed8766fb06a242.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0083.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/2a8462a69eb742f8879742a142a71bc6.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0084.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/2a8462a69eb742f8879742a142a71bc6.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0084.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/0bc6c69f230747f2b9fe0bc3823f5db1.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0085.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/0bc6c69f230747f2b9fe0bc3823f5db1.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0085.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/785d7e6930b4425f9a31fae3cc4bf63e.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0086.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/785d7e6930b4425f9a31fae3cc4bf63e.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0086.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/ca7af54dffef47e9a6816ded1e0d1b83.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0087.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/ca7af54dffef47e9a6816ded1e0d1b83.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0087.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/7bcd2f98984848259a6d29f8e3dcc380.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0088.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/7bcd2f98984848259a6d29f8e3dcc380.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0088.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/7e388a2299eb413a96604b94dc183a66.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0089.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/7e388a2299eb413a96604b94dc183a66.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0089.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/b6c65b3bb26d47d5b0a7bc14017f32e5.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0090.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/b6c65b3bb26d47d5b0a7bc14017f32e5.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0090.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/9b8ab2d2dcfa4373b3f18594332cac09.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0091.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/9b8ab2d2dcfa4373b3f18594332cac09.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0091.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/3cec994757454fc8b4612a5c1374ac0c.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0092.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/3cec994757454fc8b4612a5c1374ac0c.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0092.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/9adf9f6d7afa4124a9e407ce8d93a364.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0093.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/9adf9f6d7afa4124a9e407ce8d93a364.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0093.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/4853cafcb7454a6b97d2a6f86565ab75.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0094.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/4853cafcb7454a6b97d2a6f86565ab75.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0094.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/d78345c12ed44e7ebab0cf6068256487.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0095.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/d78345c12ed44e7ebab0cf6068256487.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0095.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/fae080f5159e4def85d1e664db21691f.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0096.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/fae080f5159e4def85d1e664db21691f.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0096.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/e6d4d73df306434ab1111c75a51bc3f7.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0097.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/e6d4d73df306434ab1111c75a51bc3f7.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0097.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/0689edf700094d79ade3f087fc32468b.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0098.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/0689edf700094d79ade3f087fc32468b.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0098.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/9ddb7d22aa8c4bcfa78a0aa8b3d9e965.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0099.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/9ddb7d22aa8c4bcfa78a0aa8b3d9e965.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0099.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/c144cd63e76c4efa9ddbe1d8f86bd4c8.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0100.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/c144cd63e76c4efa9ddbe1d8f86bd4c8.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0100.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/2f71196e4509462ebfd68b69e3fd5ea9.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0101.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/2f71196e4509462ebfd68b69e3fd5ea9.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0101.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/379e53a39db845c49e2cbaadecaed855.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0102.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/379e53a39db845c49e2cbaadecaed855.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0102.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/3e239d39005a40f492c0cf9c27157d7d.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0103.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/3e239d39005a40f492c0cf9c27157d7d.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0103.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/2e3723d847bb41198aae4d376d3708d9.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0104.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/2e3723d847bb41198aae4d376d3708d9.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0104.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/eb54cf9e7a794df3a95f5f4aedace720.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0105.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/eb54cf9e7a794df3a95f5f4aedace720.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0105.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/f95007839dea46669f8111936db37d77.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0106.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/f95007839dea46669f8111936db37d77.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0106.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/e4f5f0f19ee7450fb40d6bfe91e9e521.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0107.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/e4f5f0f19ee7450fb40d6bfe91e9e521.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0107.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/88fecc7d09dd40b289047f22b6f27fd6.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0108.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/88fecc7d09dd40b289047f22b6f27fd6.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0108.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/a8e97ca02ffc4214910584cce635f3e9.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0109.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/a8e97ca02ffc4214910584cce635f3e9.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0109.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/d57aeacbb9024f1ba74091b138c25d6e.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0110.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/d57aeacbb9024f1ba74091b138c25d6e.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0110.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/eafd84e67e2a400fb90b284d1453f852.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0111.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/eafd84e67e2a400fb90b284d1453f852.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0111.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/4808fdb8a5564d4a93536b24d65f8868.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0112.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/4808fdb8a5564d4a93536b24d65f8868.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0112.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/213a1dbadb944ccdb8b43e8e06d75625.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0113.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/213a1dbadb944ccdb8b43e8e06d75625.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0113.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/c32edb3310ff4bd3a3e8bbfaf8866226.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0114.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/c32edb3310ff4bd3a3e8bbfaf8866226.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0114.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/8b8ff7788d0e4878af2f828ccea42cec.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0115.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/8b8ff7788d0e4878af2f828ccea42cec.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0115.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/72afda664dab4ac1b062183d8821cfea.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0116.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/72afda664dab4ac1b062183d8821cfea.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0116.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/a5415fb9723c47ed9ed6f5768f4624e1.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily/cecily_manga/dataset_0117.jpg'
# ...
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/e76ba3a1eb734cdab674e69e944238cd.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0345.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/e76ba3a1eb734cdab674e69e944238cd.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0345.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/a8f94a97ee4e4d0597087c972d40ab09.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0346.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/a8f94a97ee4e4d0597087c972d40ab09.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0346.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/27226be1d3af4bfc9786c5cfd879de4b.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0347.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/27226be1d3af4bfc9786c5cfd879de4b.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0347.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/db1297935bcc44aa8b7e235bc28ea4a4.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0348.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/db1297935bcc44aa8b7e235bc28ea4a4.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0348.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/3cee76fdcb104687a9672eeb1030815b.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0349.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/3cee76fdcb104687a9672eeb1030815b.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0349.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/62e8169df36d4c5384250c14de31b29a.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0350.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/62e8169df36d4c5384250c14de31b29a.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0350.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/39a3bfb8569f49c5a17f01e372d914b9.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0351.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/39a3bfb8569f49c5a17f01e372d914b9.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0351.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/b63bd554af0b45f9bd5ddb22f00aa742.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0352.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/b63bd554af0b45f9bd5ddb22f00aa742.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0352.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/5b9d2a9884224a45ab6f7d26aed64789.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0353.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/5b9d2a9884224a45ab6f7d26aed64789.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0353.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/1a5cd67f13e4438db136e58a04db07a2.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0354.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/1a5cd67f13e4438db136e58a04db07a2.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0354.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/2f2319acc9dc4ba18469ee8e2b347fe5.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0355.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/2f2319acc9dc4ba18469ee8e2b347fe5.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0355.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/9281bbc92b744032a54aab777d037ac2.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0356.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/9281bbc92b744032a54aab777d037ac2.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0356.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/21626af2b57c49d19d1b0341c1786308.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0357.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/21626af2b57c49d19d1b0341c1786308.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0357.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/1fd2dcc492e64329aff77f3a03e8ac59.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0358.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/1fd2dcc492e64329aff77f3a03e8ac59.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0358.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/b1a3acfb0ce2494389ebb07b4d99beaf.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0359.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/b1a3acfb0ce2494389ebb07b4d99beaf.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0359.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/e51c3dac31b240d8bb92b727485ec0b0.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0360.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/e51c3dac31b240d8bb92b727485ec0b0.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0360.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/5d2d95078304430cbdda19e60d4c4593.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0361.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/5d2d95078304430cbdda19e60d4c4593.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0361.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/3ac06772893642089e615c48b5202bd8.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0362.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/3ac06772893642089e615c48b5202bd8.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0362.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/c0c79349190e4d4b847852d84cff4aad.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0363.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/c0c79349190e4d4b847852d84cff4aad.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0363.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/28430265e5c045c88608e9b2eb02b713.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0364.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/28430265e5c045c88608e9b2eb02b713.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0364.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/14d8a14ed94f4723b1bf15d8ff469d31.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0365.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/14d8a14ed94f4723b1bf15d8ff469d31.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0365.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/37e7f6e656554139bc789511ec0bc26d.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0366.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/37e7f6e656554139bc789511ec0bc26d.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0366.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/03c1e33e10d04de88f0902a5fd21f4cb.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0367.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/03c1e33e10d04de88f0902a5fd21f4cb.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0367.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/cf991509343c4cd88d6af878289ccfe6.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0368.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/cf991509343c4cd88d6af878289ccfe6.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0368.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/4d2b0efa38b145c7ad1bf6fa0f66e530.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0369.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/4d2b0efa38b145c7ad1bf6fa0f66e530.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0369.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/45638ed1e65e4e8392dfa3a3e2bc5618.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0370.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/45638ed1e65e4e8392dfa3a3e2bc5618.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0370.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/253b57f752df407f9494eaeb1aae6e33.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0371.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/253b57f752df407f9494eaeb1aae6e33.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0371.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/cdf06e5859384416b31dd677c530f004.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0372.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/cdf06e5859384416b31dd677c530f004.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0372.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/03b6839440614438b19750f979cde81d.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0373.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/03b6839440614438b19750f979cde81d.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0373.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/8b2ef5bf62414c41bbbd989cc04ab906.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0374.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/8b2ef5bf62414c41bbbd989cc04ab906.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0374.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/f988744464ae426cb5f6615380850cb5.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0375.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/f988744464ae426cb5f6615380850cb5.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0375.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/75ff225611514511bfde83aaae8d9522.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0376.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/75ff225611514511bfde83aaae8d9522.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0376.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/aa409d8af8264c8fb6394eecf34651b9.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0377.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/aa409d8af8264c8fb6394eecf34651b9.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0377.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/bdcf8617e9ba4dd699be9c25383a17d1.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0378.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/bdcf8617e9ba4dd699be9c25383a17d1.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0378.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/ba2aa2703d304434b2cd9dc04693f674.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0379.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/ba2aa2703d304434b2cd9dc04693f674.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0379.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/e07e1bcb22e444f78914a29b4a503076.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0380.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/e07e1bcb22e444f78914a29b4a503076.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0380.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/fb249fd9fe304626bd8553e1f4ef9c97.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0381.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/fb249fd9fe304626bd8553e1f4ef9c97.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0381.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/995b1cbe3193435cb032903545182690.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0382.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/995b1cbe3193435cb032903545182690.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0382.txt'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/d2b9d0944d3c4f28ae42791976e1e63e.jpg' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0383.jpg'
# Renamed '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/d2b9d0944d3c4f28ae42791976e1e63e.txt' to '/content/drive/MyDrive/Loras/cecily_noein/dataset/noein/noein_manga/dataset_0383.txt'

# %% [markdown]
# ### 📚 Multiple folders in dataset
# Below is a template allowing you to define multiple folders in your dataset. You must include the location of each folder and you can set different number of repeats for each one. To add more folders simply copy and paste the sections starting with `[[datasets.subsets]]`.
#
# When enabling this, the number of repeats set in the main cell will be ignored, and the main folder set by the project name will also be ignored.
#
# You can make one of them a regularization folder by adding `is_reg = true`
# You can also set different `keep_tokens`, `flip_aug`, etc.

# %%
custom_dataset = """
[[datasets]]

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_cg"
keep_tokens = 1
num_repeats = 1

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_manga"
keep_tokens = 1
num_repeats = 1

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_portrait"
keep_tokens = 1
num_repeats = 1

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/cecily_noein/dataset/noein"
keep_tokens = 1
num_repeats = 1

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/cecily_noein/dataset/noein_manga"
keep_tokens = 1
num_repeats = 1

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/cecily_noein/dataset/bundus"
keep_tokens = 1
num_repeats = 1

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_noein"
keep_tokens = 2
num_repeats = 1

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_noein_manga"
keep_tokens = 2
num_repeats = 1

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/cecily_noein/dataset/cecily_bundus"
keep_tokens = 2
num_repeats = 1

"""

# %%
custom_dataset = None

# %%
#@markdown ### 📂 Unzip dataset
#@markdown It's much slower to upload individual files to your Drive, so you may want to upload a zip if you have your dataset in your computer.
zip = "/content/drive/MyDrive/my_dataset.zip" #@param {type:"string"}
extract_to = "/content/drive/MyDrive/Loras/example/dataset" #@param {type:"string"}

import os, zipfile

if not os.path.exists('/content/drive'):
  from google.colab import drive
  print("📂 Connecting to Google Drive...")
  drive.mount('/content/drive')

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip, 'r') as f:
  f.extractall(extract_to)

print("✅ Done")

# %%
#@markdown ### 🔢 Count datasets
#@markdown Google Drive makes it impossible to count the files in a folder, so this will show you the file counts in all folders and subfolders.
folder = "/content/drive/MyDrive/Loras" #@param {type:"string"}

import os
from google.colab import drive

if not os.path.exists('/content/drive'):
    print("📂 Connecting to Google Drive...\n")
    drive.mount('/content/drive')

tree = {}
exclude = ("_logs", "/output")
for i, (root, dirs, files) in enumerate(os.walk(folder, topdown=True)):
  dirs[:] = [d for d in dirs if all(ex not in d for ex in exclude)]
  images = len([f for f in files if f.lower().endswith((".png", ".jpg", ".jpeg"))])
  captions = len([f for f in files if f.lower().endswith(".txt")])
  others = len(files) - images - captions
  path = root[folder.rfind("/")+1:]
  tree[path] = None if not images else f"{images:>4} images | {captions:>4} captions |"
  if tree[path] and others:
    tree[path] += f" {others:>4} other files"

pad = max(len(k) for k in tree)
print("\n".join(f"📁{k.ljust(pad)} | {v}" for k, v in tree.items() if v))
# Out:
# 📁Loras/cecily_noein/dataset/bundus                          |    6 images |    6 captions |
# 📁Loras/cecily_noein/dataset/cecily/cecily_cg                |   73 images |   73 captions |
# 📁Loras/cecily_noein/dataset/cecily/cecily_manga             |  100 images |  100 captions |
# 📁Loras/cecily_noein/dataset/cecily/cecily_portrait          |   45 images |   45 captions |
# 📁Loras/cecily_noein/dataset/cecily_bundus                   |    5 images |    5 captions |
# 📁Loras/cecily_noein/dataset/cecily_noein                    |   20 images |   20 captions |
# 📁Loras/cecily_noein/dataset/cecily_noein/cecily_noein_manga |   36 images |   36 captions |
# 📁Loras/cecily_noein/dataset/noein                           |   52 images |   52 captions |
# 📁Loras/cecily_noein/dataset/noein/noein_manga               |   47 images |   47 captions |

# %%
#@markdown ### ↪️ Continue

#@markdown Here you can write a path in your Google Drive to load an existing Lora file to continue training on.<p>
#@markdown **Warning:** It's not the same as one long training session. The epochs start from scratch, and it may have worse results.
continue_from_lora = "" #@param {type:"string"}
if continue_from_lora and not continue_from_lora.startswith("/content/drive/MyDrive"):
  import os
  continue_from_lora = os.path.join("/content/drive/MyDrive", continue_from_lora)

# %% [markdown]
# # 📈 Plot training results
# You can do this after running the trainer. You don't need this unless you know what you're doing.
# The first cell below may fail to load all your logs. Keep trying the second cell until all data has loaded.

# %%
# %load_ext tensorboard
# %tensorboard --logdir={log_folder}/

# %%
from tensorboard import notebook
notebook.display(port=6006, height=800)
